# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as Stats

# %%
cars=pd.read_csv('Cars.csv')

# %%
cars
# Out:
#      HP        MPG  VOL          SP         WT
# 0    49  53.700681   89  104.185353  28.762059
# 1    55  50.013401   92  105.461264  30.466833
# 2    55  50.013401   92  105.461264  30.193597
# 3    70  45.696322   92  113.461264  30.632114
# 4    53  50.504232   92  104.461264  29.889149
# ..  ...        ...  ...         ...        ...
# 76  322  36.900000   50  169.598513  16.132947
# 77  238  19.197888  115  150.576579  37.923113
# 78  263  34.000000   50  151.598513  15.769625
# 79  295  19.833733  119  167.944460  39.423099
# 80  236  12.101263  107  139.840817  34.948615
#
# [81 rows x 5 columns]

# %%
cars.mean()
# Out:
# HP     117.469136
# MPG     34.422076
# VOL     98.765432
# SP     121.540272
# WT      32.412577
# dtype: float64

# %%
cars.median()
# Out:
# HP     100.000000
# MPG     35.152727
# VOL    101.000000
# SP     118.208698
# WT      32.734518
# dtype: float64

# %%
cars.mode()
# Out:
#       HP        MPG   VOL          SP         WT
# 0   92.0  29.629936  50.0  118.288996  15.712859
# 1    NaN        NaN   NaN         NaN  15.753535
# 2    NaN        NaN   NaN         NaN  15.769625
# 3    NaN        NaN   NaN         NaN  15.823060
# 4    NaN        NaN   NaN         NaN  15.847758
# ..   ...        ...   ...         ...        ...
# 76   NaN        NaN   NaN         NaN  42.778219
# 77   NaN        NaN   NaN         NaN  43.353123
# 78   NaN        NaN   NaN         NaN  43.390988
# 79   NaN        NaN   NaN         NaN  44.013139
# 80   NaN        NaN   NaN         NaN  52.997752
#
# [81 rows x 5 columns]

# %%
cars.rename(columns={'HP':'hp'},inplace= True)

# %%
cars
# Out:
#      hp        MPG  VOL          SP         WT
# 0    49  53.700681   89  104.185353  28.762059
# 1    55  50.013401   92  105.461264  30.466833
# 2    55  50.013401   92  105.461264  30.193597
# 3    70  45.696322   92  113.461264  30.632114
# 4    53  50.504232   92  104.461264  29.889149
# ..  ...        ...  ...         ...        ...
# 76  322  36.900000   50  169.598513  16.132947
# 77  238  19.197888  115  150.576579  37.923113
# 78  263  34.000000   50  151.598513  15.769625
# 79  295  19.833733  119  167.944460  39.423099
# 80  236  12.101263  107  139.840817  34.948615
#
# [81 rows x 5 columns]

# %%
cars.describe()
# Out:
#                hp        MPG         VOL          SP         WT
# count   81.000000  81.000000   81.000000   81.000000  81.000000
# mean   117.469136  34.422076   98.765432  121.540272  32.412577
# std     57.113502   9.131445   22.301497   14.181432   7.492813
# min     49.000000  12.101263   50.000000   99.564907  15.712859
# 25%     84.000000  27.856252   89.000000  113.829145  29.591768
# 50%    100.000000  35.152727  101.000000  118.208698  32.734518
# 75%    140.000000  39.531633  113.000000  126.404312  37.392524
# max    322.000000  53.700681  160.000000  169.598513  52.997752

# %%
plt.hist(cars["hp"],bins=20,edgecolor='black')
# Out:
# (array([ 8.,  7.,  7., 28.,  5.,  4.,  4.,  2.,  7.,  2.,  0.,  0.,  0.,
#          2.,  1.,  1.,  1.,  0.,  1.,  1.]),
#  array([ 49.  ,  62.65,  76.3 ,  89.95, 103.6 , 117.25, 130.9 , 144.55,
#         158.2 , 171.85, 185.5 , 199.15, 212.8 , 226.45, 240.1 , 253.75,
#         267.4 , 281.05, 294.7 , 308.35, 322.  ]),
#  <BarContainer object of 20 artists>)

# %%
plt.boxplot(x='hp',data=cars)
plt.xlabel('hp')
plt.ylabel('wt')
plt.savefig("pointsinference.png")
plt.show()

# %%
plt.figure(figsize=(16,9))
plt.barh(cars['hp'],cars['MPG'])
plt.yticks(fontsize=14)
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.plot(cars.index)
plt.xlabel('hp')
plt.ylabel('wt')
plt.show()

# %%
sns.distplot(cars.index,label='Cars.csv')
plt.xlabel('hp')
plt.ylabel('wt')
plt.legend()
plt.show()
# Out:
# C:\Users\subhr\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.scatterplot(cars.index,label='Cars.csv')
plt.xlabel('hp')
plt.ylabel('wt')
plt.legend()
plt.show()
# Out:
# C:\Users\subhr\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.hist(cars["MPG"], bins = 20, edgecolor=  'black')
plt.show()

# %%
plt.boxplot(x= 'MPG', data =cars)
plt.show()

# %%
sns.distplot(cars['MPG'],kde=True, bins =10)
plt.show()
# Out:
# C:\Users\subhr\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
import statsmodels.api as sm
sm.qqplot(cars['MPG'])
plt.xlabel('MPG', color ='blue')
plt.savefig('MPG of cars.png')
plt.show()

# %%
import scipy.stats as stats
stats.probplot(cars['MPG'], dist="norm", plot=plt)
plt.xlabel('MPG', color ='blue')
plt.savefig('MPG of cars.png')
plt.show()

# %%
import seaborn as sb
